# %%
import pandas as pd
# %run utils.ipynb

# %%
path = 'D:/Learn/projects/data/job_data/apify/'
file_name = '01152025_linkedin_fin'
upload_path = f'{path}{file_name}.csv'
download_path = f'{path}{file_name}_processed.csv'
print(upload_path)
print(download_path)
# Out:
# D:/Learn/projects/data/job_data/apify/01152025_linkedin_fin.csv
# D:/Learn/projects/data/job_data/apify/01152025_linkedin_fin_processed.csv

# %%
df = pd.read_csv(upload_path)
df.columns
# Out:
# Index(['applicationsCount', 'applyType', 'applyUrl', 'benefits', 'companyId',
#        'companyName', 'companyUrl', 'contractType', 'description',
#        'experienceLevel', 'id', 'jobUrl', 'location', 'postedTime',
#        'posterFullName', 'posterProfileUrl', 'publishedAt', 'salary', 'sector',
#        'title', 'workType'],
#       dtype='object')

# %%
cols_to_keep = ['description','id','location', 'salary']
df1 = df[cols_to_keep]
df2 = df1.head(24)

# %%
# %run utils_ai.ipynb

df3 = batch_process(df2)
# Out:
# Processing batch with 12 rows at index 12...
# ...
