# %%
import pandas as pd
from utils import refine, standard_location, remove_non_english_jobs, simplify_titles_finance, parse_description, parse_salary, standard_skills
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cheny\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cheny\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# read data
path = 'D:/Learn/projects/data/job_data/apify/01152025_linkedin_fin.csv'
df = pd.read_csv(path)
df.head(3)
# Out:
#                   applicationsCount   applyType  \
# 0  Be among the first 25 applicants  EASY_APPLY
# 1                     32 applicants  EASY_APPLY
# 2  Be among the first 25 applicants  EASY_APPLY
#
#                                             applyUrl  \
# 0  https://www.linkedin.com/jobs/view/financial-d...
# 1  https://www.linkedin.com/jobs/view/sr-manager-...
# 2  https://www.linkedin.com/jobs/view/chief-finan...
#
#                                             benefits  companyId  \
# 0  401(k)\nDental insurance\nMedical insurance\nV...  1215629.0
# 1                                                NaN    30086.0
# 2                                                NaN   766746.0
#
#                           companyName  \
# 0                      Atlantic Group
# 1                  Palo Alto Networks
# 2  Piping Technology & Products, Inc.
#
#                                           companyUrl contractType  \
# 0  https://www.linkedin.com/company/the-atlantic-...    Full-time
# 1  https://www.linkedin.com/company/palo-alto-net...    Full-time
# 2  https://www.linkedin.com/company/piping-techno...    Full-time
#
#                                          description   experienceLevel  ...  \
# 0  Our Client, A top tier PE firm is looking to h...         Executive  ...
# 1  Our Mission\n\nAt Palo Alto Networks® everythi...  Mid-Senior level  ...
# 2  Company Overview\n\nPiping Technology & Produc...         Executive  ...
#
#                                               jobUrl                 location  \
# 0  https://www.linkedin.com/jobs/view/financial-d...  New York, United States
# 1  https://www.linkedin.com/jobs/view/sr-manager-...          Santa Clara, CA
# 2  https://www.linkedin.com/jobs/view/chief-finan...              Houston, TX
#
#      postedTime posterFullName posterProfileUrl publishedAt  \
# 0   9 hours ago            NaN              NaN  2025-01-16
# 1   8 hours ago            NaN              NaN  2025-01-16
# 2  10 hours ago            NaN              NaN  2025-01-16
#
#                             salary                         sector  \
# 0  $200,000.00/yr - $250,000.00/yr        Staffing and Recruiting
# 1                              NaN  Computer and Network Security
# 2                              NaN  IT Services and IT Consulting
#
#                                 title                         workType
# 0  Financial Director, Private Equity  Accounting/Auditing and Finance
# 1     Sr Manager of Strategic Finance                          Finance
# 2             Chief Financial Officer              Accounting/Auditing
#
# [3 rows x 21 columns]

# %%
# remove empty and duplicated data
df1 = refine(df)
df1.info()
# Out:
# Processing...length of data 688
# droped empty rows, remaining 682
# droped duplicates, remaining 642
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                642 non-null    int64
#  1   publishedAt       642 non-null    object
#  2   title             642 non-null    object
#  3   location          642 non-null    object
#  4   salary            253 non-null    object
#  5   applyUrl          642 non-null    object
#  6   jobUrl            642 non-null    object
#  7   contractType      642 non-null    object
#  8   sector            639 non-null    object
#  9   workType          642 non-null    object
#  10  description       642 non-null    object
#  11  benefits          117 non-null    object
#  12  companyId         642 non-null    float64
#  13  companyName       642 non-null    object
#  14  companyUrl        642 non-null    object
#  15  experienceLevel   642 non-null    object
#  16  posterFullName    179 non-null    object
#  17  posterProfileUrl  179 non-null    object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 90.4+ KB

# %%
df2 = remove_non_english_jobs(df1)
df2.info()
# Out:
# Index(['id', 'publishedAt', 'title', 'location', 'salary', 'applyUrl',
#        'jobUrl', 'contractType', 'sector', 'workType', 'description',
#        'benefits', 'companyId', 'companyName', 'companyUrl', 'experienceLevel',
#        'posterFullName', 'posterProfileUrl'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                642 non-null    int64
#  1   publishedAt       642 non-null    object
#  2   title             642 non-null    object
#  3   location          642 non-null    object
#  4   salary            253 non-null    object
#  5   applyUrl          642 non-null    object
#  6   jobUrl            642 non-null    object
#  7   contractType      642 non-null    object
#  8   sector            639 non-null    object
#  9   workType          642 non-null    object
#  10  description       642 non-null    object
#  11  benefits          117 non-null    object
#  12  companyId         642 non-null    float64
#  13  companyName       642 non-null    object
#  14  companyUrl        642 non-null    object
#  15  experienceLevel   642 non-null    object
#  16  posterFullName    179 non-null    object
#  17  posterProfileUrl  179 non-null    object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 90.4+ KB

# %%
# standardize location
df3 = standard_location(df2)
# Out:
# Start API call at ID: location, Retry: 0
# Retrieved dictionary at ID: location
# {city}, {state}"
#     elif "Dallas-Fort Worth" in loc:
#         return "Dallas-Fort Worth, TX"
#     elif "Greater" in loc:
#         return f"{loc.split(' ')[1]}, TX"
#     elif "Atlanta" in loc:
#         return "Atlanta, GA"
#     elif "Austin" in loc:
#         return "Austin, TX"
#     elif "Nashville" in loc:
#         return "Nashville, TN"
#     elif "Rochester" in loc:
#         return "Rochester, NY"
#     elif "San Diego" in loc:
#         return "San Diego, CA"
#     elif "Chicago" in loc:
#         return "Chicago, IL"
#     elif "Houston" in loc:
#         return "Houston, TX"
#     elif "Cincinnati" in loc:
#         return "Cincinnati, OH"
#     elif "Denver" in loc:
#         return "Denver, CO"
#     elif "Topeka" in loc:
#         return "Topeka, KS"
#     elif "Columbia" in loc:
#         return "Columbia, SC"
#     elif "Des Moines" in loc:
#         return "Des Moines, IA"
#     elif "Jacksonville" in loc:
#         return "Jacksonville, FL"
#     elif "Seattle" in loc:
#         return "Seattle, WA"
#     else:
#         return loc  # Return the location as is if not recognized
#
# # Creating the dictionary
# location_mapping = {location: format_location(location) for location in locations}
#
# # Printing the resulting dictionary
# for key, value in location_mapping.items():
#     print(f"{key}: {value}
# Invalid JSON content at ID: location, attempting eval...
# Error during API call or processing at ID: location: unterminated string literal (detected at line 1) (<unknown>, line 1)
# Retrying 1... Waiting before next attempt.
# Start API call at ID: location, Retry: 1
# Retrieved dictionary at ID: location
# {
#     "Dallas-Fort Worth Metroplex": "Dallas, TX",
#     "Greater Houston": "Houston, TX",
#     "Greater Tampa Bay Area": "Tampa, FL",
#     "New York City Metropolitan Area": "New York, NY",
#     "Rochester, New York Metropolitan Area": "Rochester, NY",
#     "Greater Chicago Area": "Chicago, IL",
#     "Nashville Metropolitan Area": "Nashville, TN",
#     "Greater Seattle Area": "Seattle, WA",
#     "San Diego Metropolitan Area": "San Diego, CA",
#     "Kansas City Metropolitan Area": "Kansas City, MO",
#     "Columbia, South Carolina Metropolitan Area": "Columbia, SC",
#     "Denver Metropolitan Area": "Denver, CO",
#     "Detroit Metropolitan Area": "Detroit, MI",
#     "Des Moines Metropolitan Area": "Des Moines, IA",
#     "Topeka Metropolitan Area": "Topeka, KS",
#     "Greater Boston": "Boston, MA",
#     "Austin, Texas Metropolitan Area": "Austin, TX",
#     "Atlanta Metropolitan Area": "Atlanta, GA",
#     "Metro Jacksonville": "Jacksonville, FL",
#     "Cincinnati Metropolitan Area": "Cincinnati, OH"
# }

# %%
# simplify title
df4 = df3.apply(simplify_titles_finance, axis=1).copy()
# df3['title_simplified'].value_counts()

# %%
df4.to_csv('01152025_linkedin_fin_location_title', index=False)

# %%
df4 = pd.read_csv('01152025_linkedin_fin_location_title')

# %%
# call openai api to process description, obtain degree, experience, and skill requirements
df5 = parse_description(df4)
# Out:
# Start API call at ID: 4126545357, Retry: 0
# Retrieved dictionary at ID: 4126545357
# {
#     "min_years_of_experience": 12,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "auditing", "financial reporting"]
# }
# Invalid JSON content at ID: 4126545357, attempting eval...
# Start API call at ID: 4125546958, Retry: 0
# Retrieved dictionary at ID: 4125546958
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 250000,
#     "max_yearly_salary": 441000,
#     "degree": "BS",
#     "skills": [
#         "operational",
#         "collaboration",
#         "communication",
#         "partnerships",
#         "strategic"
#     ]
# }
# Start API call at ID: 4126543125, Retry: 0
# Retrieved dictionary at ID: 4126543125
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 128100,
#     "max_yearly_salary": 213400,
#     "degree": "BS",
#     "skills": ["SharePoint", "Microsoft Word", "Excel", "PowerPoint", "Teams", "Visio", "Project"]
# }
# Start API call at ID: 4125231595, Retry: 0
# Retrieved dictionary at ID: 4125231595
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "FP&A", "financial modeling", "forecasting"]
# }
# Invalid JSON content at ID: 4125231595, attempting eval...
# Start API call at ID: 4125671935, Retry: 0
# Retrieved dictionary at ID: 4125671935
# {
#     "min_years_of_experience": 15,
#     "min_yearly_salary": 263000,
#     "max_yearly_salary": 275000,
#     "degree": "BS",
#     "skills": [
#         "risk management",
#         "change management",
#         "public private partnerships",
#         "financial agreements",
#         "project finance",
#         "quality management"
#     ]
# }
# Start API call at ID: 4126523247, Retry: 0
# Retrieved dictionary at ID: 4126523247
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 54072,
#     "max_yearly_salary": 72852,
#     "degree": "BS",
#     "skills": [
#         "Microsoft Office",
#         "Accounts Payable Process",
#         "General Ledger",
#         "ERP Solutions",
#         "Communication",
#         "Process Reviews",
#         "Financial Accounting",
#         "Troubleshooting",
#         "Teamwork",
#         "Customer Service",
#         "Preparation of Financial Reports",
#         "Microsoft Power Business Intelligence"
#     ]
# }
# Invalid JSON content at ID: 4126523247, attempting eval...
# Start API call at ID: 4126673176, Retry: 0
# Retrieved dictionary at ID: 4126673176
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "GAAP", "financial reporting", "Microsoft Excel", "problem-solving", "attention to detail", "communication"]
# }
# Invalid JSON content at ID: 4126673176, attempting eval...
# Start API call at ID: 4124633666, Retry: 0
# Retrieved dictionary at ID: 4124633666
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 185000,
#     "max_yearly_salary": 304000,
#     "degree": "PHD",
#     "skills": ["teaching", "research"]
# }
# Invalid JSON content at ID: 4124633666, attempting eval...
# Start API call at ID: 4125111151, Retry: 0
# Retrieved dictionary at ID: 4125111151
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["procurement", "supply chain", "negotiation", "market analysis", "Microsoft", "financial management"]
# }
# Invalid JSON content at ID: 4125111151, attempting eval...
# Start API call at ID: 4126521183, Retry: 0
# Retrieved dictionary at ID: 4126521183
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 73000,
#     "max_yearly_salary": 117300,
#     "degree": "BS",
#     "skills": ["Microsoft Excel", "communication", "collaboration"]
# }
# Start API call at ID: 4126613414, Retry: 0
# Retrieved dictionary at ID: 4126613414
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["leadership", "financial modeling", "communication", "attention to detail", "technical skills"]
# }
# Invalid JSON content at ID: 4126613414, attempting eval...
# Start API call at ID: 4125652348, Retry: 0
# Retrieved dictionary at ID: 4125652348
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial modeling",
#         "research",
#         "analysis",
#         "presentations",
#         "market trends",
#         "acquisitions",
#         "due diligence",
#         "communication",
#         "problem-solving",
#         "financial acumen",
#         "Excel",
#         "PowerPoint",
#         "Word"
#     ]
# }
# Invalid JSON content at ID: 4125652348, attempting eval...
# Start API call at ID: 4125162210, Retry: 0
# Retrieved dictionary at ID: 4125162210
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 65000,
#     "max_yearly_salary": 70000,
#     "degree": "BS",
#     "skills": ["QuickBooks", "ADP", "Excel", "payroll processing", "tax regulations", "compliance"]
# }
# Start API call at ID: 4126504971, Retry: 0
# Retrieved dictionary at ID: 4126504971
# {
#     "min_years_of_experience": 12,
#     "min_yearly_salary": 200000,
#     "max_yearly_salary": 250000,
#     "degree": "BS",
#     "skills": ["sales", "business development", "relationship management", "investment solutions", "communication", "presentation"]
# }
# Start API call at ID: 4125123632, Retry: 0
# Retrieved dictionary at ID: 4125123632
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "BRIX", "accounting principles", "attention to detail"]
# }
# Invalid JSON content at ID: 4125123632, attempting eval...
# Start API call at ID: 4125557154, Retry: 0
# Retrieved dictionary at ID: 4125557154
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["finance", "analytical", "communication"]
# }
# Invalid JSON content at ID: 4125557154, attempting eval...
# Start API call at ID: 4126526091, Retry: 0
# Retrieved dictionary at ID: 4126526091
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 54072,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "data analysis",
#         "communication",
#         "project management",
#         "data visualization",
#         "SQL",
#         "statistics",
#         "organizational skills"
#     ]
# }
# Invalid JSON content at ID: 4126526091, attempting eval...
# Start API call at ID: 4124683192, Retry: 0
# Retrieved dictionary at ID: 4124683192
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["sales", "financial data", "project management", "P&L drivers", "forecasting"]
# }
# Invalid JSON content at ID: 4124683192, attempting eval...
# Start API call at ID: 4126500646, Retry: 0
# Retrieved dictionary at ID: 4126500646
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Deltek Vision", "AEC", "MS Office", "communication", "initiative", "attention to detail"]
# }
# Invalid JSON content at ID: 4126500646, attempting eval...
# Start API call at ID: 4124669171, Retry: 0
# Retrieved dictionary at ID: 4124669171
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": 17460,
#     "max_yearly_salary": 25910,
#     "degree": "BS",
#     "skills": [
#         "billing",
#         "insurance",
#         "communication",
#         "confidentiality",
#         "math",
#         "computer"
#     ]
# }
# Start API call at ID: 4124682200, Retry: 0
# Retrieved dictionary at ID: 4124682200
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["communication", "finance", "SAP"]
# }
# Invalid JSON content at ID: 4124682200, attempting eval...
# Start API call at ID: 4125166628, Retry: 0
# Retrieved dictionary at ID: 4125166628
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125166628, attempting eval...
# Start API call at ID: 4124617802, Retry: 0
# Retrieved dictionary at ID: 4124617802
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 85000,
#     "degree": "BS",
#     "skills": [
#         "interpersonal",
#         "relationship management",
#         "Microsoft Office Suite",
#         "Concur",
#         "SharePoint",
#         "Box",
#         "project management"
#     ]
# }
# Start API call at ID: 4125128727, Retry: 0
# Retrieved dictionary at ID: 4125128727
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["corporate banking", "Finastra"]
# }
# Invalid JSON content at ID: 4125128727, attempting eval...
# Start API call at ID: 4125170027, Retry: 0
# Retrieved dictionary at ID: 4125170027
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "communication", "analytical", "forecasting", "budgeting", "Excel", "Microsoft Office", "dealership management"]
# }
# Invalid JSON content at ID: 4125170027, attempting eval...
# Start API call at ID: 4125224339, Retry: 0
# Retrieved dictionary at ID: 4125224339
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 120579,
#     "max_yearly_salary": 156755,
#     "degree": "BS",
#     "skills": ["financial management", "accounting", "budgeting", "analytical skills", "reporting", "forecasting"]
# }
# Start API call at ID: 4124673967, Retry: 0
# Retrieved dictionary at ID: 4124673967
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["SQL", "PowerBI", "Tableau", "financial institutions", "ALM", "Interest Rate Risk", "Non-Maturity deposit modeling", "Liquidity"]
# }
# Invalid JSON content at ID: 4124673967, attempting eval...
# Start API call at ID: 4125124167, Retry: 0
# Retrieved dictionary at ID: 4125124167
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 101401,
#     "max_yearly_salary": 131826,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125124167, attempting eval...
# Start API call at ID: 4126524055, Retry: 0
# Retrieved dictionary at ID: 4126524055
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": [
#         "accounting",
#         "GAAP",
#         "financial reporting",
#         "ERP",
#         "Sage Intacct",
#         "QuickBooks",
#         "Microsoft",
#         "financial analysis",
#         "cash management",
#         "leadership"
#     ]
# }
# Invalid JSON content at ID: 4126524055, attempting eval...
# Start API call at ID: 4125237157, Retry: 0
# Retrieved dictionary at ID: 4125237157
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 125000,
#     "max_yearly_salary": 200000,
#     "degree": "BS",
#     "skills": ["private equity", "due diligence", "CPA", "investor relations", "financial analysis"]
# }
# Start API call at ID: 4126633661, Retry: 0
# Retrieved dictionary at ID: 4126633661
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "leadership",
#         "communication",
#         "analytical",
#         "problem solving",
#         "marketing"
#     ]
# }
# Invalid JSON content at ID: 4126633661, attempting eval...
# Start API call at ID: 4124621683, Retry: 0
# Retrieved dictionary at ID: 4124621683
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "accounting software", "ERP systems", "NetSuite", "Prendio"]
# }
# Invalid JSON content at ID: 4124621683, attempting eval...
# Start API call at ID: 4125161101, Retry: 0
# Retrieved dictionary at ID: 4125161101
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "accounting",
#         "finance",
#         "M&A",
#         "GAAP",
#         "financial modeling",
#         "data analysis",
#         "Excel"
#     ]
# }
# Invalid JSON content at ID: 4125161101, attempting eval...
# Start API call at ID: 4125133163, Retry: 0
# Retrieved dictionary at ID: 4125133163
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": 85000,
#     "max_yearly_salary": 110000,
#     "degree": "BS",
#     "skills": [
#         "financial analysis",
#         "valuation",
#         "financial modeling",
#         "advanced excel",
#         "interpersonal skills"
#     ]
# }
# Start API call at ID: 4124697528, Retry: 0
# Retrieved dictionary at ID: 4124697528
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial control",
#         "risk analysis",
#         "data analysis",
#         "investment models",
#         "compliance",
#         "effective communication",
#         "technical guidance",
#         "project management",
#         "budgeting",
#         "strategic planning"
#     ]
# }
# Invalid JSON content at ID: 4124697528, attempting eval...
# Start API call at ID: 4124674225, Retry: 0
# Retrieved dictionary at ID: 4124674225
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "SAP"]
# }
# Invalid JSON content at ID: 4124674225, attempting eval...
# Start API call at ID: 4125126326, Retry: 0
# Retrieved dictionary at ID: 4125126326
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 90000,
#     "max_yearly_salary": 100000,
#     "degree": "BS",
#     "skills": [
#         "GAAP",
#         "Excel",
#         "SQL",
#         "financial forecasting",
#         "corporate finance",
#         "problem-solving",
#         "multitasking",
#         "Microsoft Office"
#     ]
# }
# Start API call at ID: 4126619598, Retry: 0
# Retrieved dictionary at ID: 4126619598
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accrual accounting", "job costing", "Deltek"]
# }
# Invalid JSON content at ID: 4126619598, attempting eval...
# Start API call at ID: 4125249010, Retry: 0
# Retrieved dictionary at ID: 4125249010
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 77800,
#     "max_yearly_salary": 97250,
#     "degree": "BS",
#     "skills": ["Microsoft Office", "Excel", "PeopleSoft", "Cognos"]
# }
# Start API call at ID: 4126178361, Retry: 0
# Retrieved dictionary at ID: 4126178361
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "Power Query", "ERP", "Power BI", "accounting", "financial analysis"]
# }
# Invalid JSON content at ID: 4126178361, attempting eval...
# Start API call at ID: 4125529821, Retry: 0
# Retrieved dictionary at ID: 4125529821
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": ["finance", "structured finance", "risk assessment", "business development", "communication"]
# }
# Invalid JSON content at ID: 4125529821, attempting eval...
# Start API call at ID: 4125142658, Retry: 0
# Retrieved dictionary at ID: 4125142658
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": [
#         "bookkeeping",
#         "invoices",
#         "accruals",
#         "costings",
#         "analysis",
#         "pricing",
#         "cash flows",
#         "tax returns",
#         "customer vetting",
#         "financial management",
#         "P&L",
#         "Balance sheets",
#         "financial statements"
#     ]
# }
# Invalid JSON content at ID: 4125142658, attempting eval...
# Start API call at ID: 4126693937, Retry: 0
# Retrieved dictionary at ID: 4126693937
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["bookkeeping", "accounting", "QuickBooks", "Excel", "Google Sheets", "financial statements", "accounts payable", "accounts receivable", "analytical", "problem-solving", "communication"]
# }
# Invalid JSON content at ID: 4126693937, attempting eval...
# Start API call at ID: 4125126530, Retry: 0
# Retrieved dictionary at ID: 4125126530
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": 160000,
#     "max_yearly_salary": 210000,
#     "degree": "MS",
#     "skills": ["credit", "finance", "VB", "Python", "SQL"]
# }
# Start API call at ID: 4126633255, Retry: 0
# Retrieved dictionary at ID: 4126633255
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["MS Project", "Excel", "MS Word", "PowerPoint", "communication", "presentation", "problem-solving"]
# }
# Invalid JSON content at ID: 4126633255, attempting eval...
# Start API call at ID: 4126618773, Retry: 0
# Retrieved dictionary at ID: 4126618773
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["risk management", "compliance", "AML", "BSA", "payments", "fintech", "electronic transfers", "analytical skills", "fraud detection"]
# }
# Invalid JSON content at ID: 4126618773, attempting eval...
# Start API call at ID: 4126518941, Retry: 0
# Retrieved dictionary at ID: 4126518941
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 100000,
#     "degree": "AS",
#     "skills": ["people skills", "work ethic", "entrepreneurial spirit", "financial planning", "marketing techniques"]
# }
# Invalid JSON content at ID: 4126518941, attempting eval...
# Start API call at ID: 4126566642, Retry: 0
# Retrieved dictionary at ID: 4126566642
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "real estate",
#         "finance",
#         "communication",
#         "negotiation",
#         "Excel",
#         "Argus"
#     ]
# }
# Invalid JSON content at ID: 4126566642, attempting eval...
# Start API call at ID: 4126538755, Retry: 0
# Retrieved dictionary at ID: 4126538755
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "management",
#         "financial data",
#         "outpatient",
#         "treatment",
#         "communication",
#         "time management"
#     ]
# }
# Invalid JSON content at ID: 4126538755, attempting eval...
# Start API call at ID: 4126536920, Retry: 0
# Retrieved dictionary at ID: 4126536920
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial data",
#         "outpatient",
#         "Medical Assisted Treatment",
#         "drug abuse",
#         "communication",
#         "time management",
#         "coaching",
#         "management"
#     ]
# }
# Invalid JSON content at ID: 4126536920, attempting eval...
# Start API call at ID: 4126528025, Retry: 0
# Retrieved dictionary at ID: 4126528025
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": 55548,
#     "max_yearly_salary": 83136,
#     "degree": "MS",
#     "skills": ["budgeting", "data analysis"]
# }
# Start API call at ID: 4125122833, Retry: 0
# Retrieved dictionary at ID: 4125122833
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": [
#         "operational excellence",
#         "team management",
#         "budgeting",
#         "customer service",
#         "analytical skills",
#         "leadership",
#         "communication skills",
#         "real estate",
#         "property management"
#     ]
# }
# Invalid JSON content at ID: 4125122833, attempting eval...
# Start API call at ID: 4119100560, Retry: 0
# Retrieved dictionary at ID: 4119100560
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "logistics",
#         "management",
#         "sales",
#         "warehousing",
#         "customer service",
#         "strategic planning",
#         "resource allocation",
#         "leadership",
#         "analysis"
#     ]
# }
# Invalid JSON content at ID: 4119100560, attempting eval...
# Start API call at ID: 4125123244, Retry: 0
# Retrieved dictionary at ID: 4125123244
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": 150000,
#     "max_yearly_salary": 165000,
#     "degree": None,
#     "skills": ["accounting", "team management", "financial analysis", "financial planning", "compliance"]
# }
# Invalid JSON content at ID: 4125123244, attempting eval...
# Start API call at ID: 4125548792, Retry: 0
# Retrieved dictionary at ID: 4125548792
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial analysis", "financial reporting", "liquidity management", "Excel", "Power BI"]
# }
# Invalid JSON content at ID: 4125548792, attempting eval...
# Start API call at ID: 4125113438, Retry: 0
# Retrieved dictionary at ID: 4125113438
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "cost accounting", "financial reporting", "manufacturing", "leadership", "communication", "ERP"]
# }
# Invalid JSON content at ID: 4125113438, attempting eval...
# Start API call at ID: 4126525842, Retry: 0
# Retrieved dictionary at ID: 4126525842
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial management", "construction accounting", "leadership", "Excel", "budgeting", "forecasting"]
# }
# Invalid JSON content at ID: 4126525842, attempting eval...
# Start API call at ID: 4125114021, Retry: 0
# Retrieved dictionary at ID: 4125114021
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["month end close", "reconciliations", "financial reporting"]
# }
# Invalid JSON content at ID: 4125114021, attempting eval...
# Start API call at ID: 4126621374, Retry: 0
# Retrieved dictionary at ID: 4126621374
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": [
#         "financial",
#         "P&L",
#         "problem-solving",
#         "conflict-resolution",
#         "motivational"
#     ]
# }
# Invalid JSON content at ID: 4126621374, attempting eval...
# Start API call at ID: 4125240231, Retry: 0
# Retrieved dictionary at ID: 4125240231
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "contract review",
#         "attention to detail",
#         "analytical skills",
#         "organizational skills",
#         "Microsoft Office",
#         "contract management"
#     ]
# }
# Invalid JSON content at ID: 4125240231, attempting eval...
# Start API call at ID: 4126696855, Retry: 0
# Retrieved dictionary at ID: 4126696855
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Finance", "Business Administration", "Accounting", "Revenue Management", "Value Creation"]
# }
# Invalid JSON content at ID: 4126696855, attempting eval...
# Start API call at ID: 4126538752, Retry: 0
# Retrieved dictionary at ID: 4126538752
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "leadership",
#         "financial analysis",
#         "outpatient management",
#         "drug abuse knowledge",
#         "team building",
#         "coaching"
#     ]
# }
# Invalid JSON content at ID: 4126538752, attempting eval...
# Start API call at ID: 4126540593, Retry: 0
# Retrieved dictionary at ID: 4126540593
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "management",
#         "financial data",
#         "outpatient",
#         "Medical Assisted Treatment",
#         "drug abuse",
#         "treatment",
#         "communication",
#         "time management",
#         "coaching"
#     ]
# }
# Invalid JSON content at ID: 4126540593, attempting eval...
# Start API call at ID: 4126622167, Retry: 0
# Retrieved dictionary at ID: 4126622167
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Accounting", "GAAP", "analytical", "PDI", "QuickBooks", "NetSuite", "Microsoft Office", "Excel"]
# }
# Invalid JSON content at ID: 4126622167, attempting eval...
# Start API call at ID: 4126537190, Retry: 0
# Retrieved dictionary at ID: 4126537190
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "negotiation",
#         "contract management",
#         "communication",
#         "interpersonal",
#         "problem solving",
#         "detail oriented",
#         "computer literacy"
#     ]
# }
# Invalid JSON content at ID: 4126537190, attempting eval...
# Start API call at ID: 4124675372, Retry: 0
# Retrieved dictionary at ID: 4124675372
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": [
#         "compliance",
#         "fraud",
#         "anti-money laundering",
#         "Bank Secrecy Act",
#         "banking systems",
#         "monitoring tools",
#         "financial crime detection"
#     ]
# }
# Invalid JSON content at ID: 4124675372, attempting eval...
# Start API call at ID: 4126503798, Retry: 0
# Retrieved dictionary at ID: 4126503798
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "SEC reporting",
#         "US GAAP",
#         "financial analysis",
#         "automation",
#         "CPA"
#     ]
# }
# Invalid JSON content at ID: 4126503798, attempting eval...
# Start API call at ID: 4125203829, Retry: 0
# Retrieved dictionary at ID: 4125203829
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "leadership",
#         "accounting",
#         "finance",
#         "GAAP",
#         "strategic",
#         "analytical"
#     ]
# }
# Invalid JSON content at ID: 4125203829, attempting eval...
# Start API call at ID: 4126565649, Retry: 0
# Retrieved dictionary at ID: 4126565649
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "analytical", "organizational", "attention to detail", "relationship development"]
# }
# Invalid JSON content at ID: 4126565649, attempting eval...
# Start API call at ID: 4126529184, Retry: 0
# Retrieved dictionary at ID: 4126529184
# {
#     "min_years_of_experience": 15,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "leadership",
#         "project management",
#         "construction software",
#         "DOT regulations"
#     ]
# }
# Invalid JSON content at ID: 4126529184, attempting eval...
# Start API call at ID: 4125162911, Retry: 0
# Retrieved dictionary at ID: 4125162911
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 54072,
#     "max_yearly_salary": 72792,
#     "degree": "BS",
#     "skills": [
#         "Data Analysis",
#         "Business Intelligence",
#         "Optimization Software",
#         "Supply Chain",
#         "Supply Chain Strategies",
#         "Microsoft PowerPoint",
#         "Presenting",
#         "Project Management",
#         "Design Thinking",
#         "Statistical Analysis",
#         "Teamwork"
#     ]
# }
# Invalid JSON content at ID: 4125162911, attempting eval...
# Start API call at ID: 4126568246, Retry: 0
# Retrieved dictionary at ID: 4126568246
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["US GAAP", "revenue recognition", "NetSuite", "financial records", "accounting principles", "financial reporting", "Excel"]
# }
# Invalid JSON content at ID: 4126568246, attempting eval...
# Start API call at ID: 4124640830, Retry: 0
# Retrieved dictionary at ID: 4124640830
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["SAP", "IFRS", "GAAP", "communication"]
# }
# Invalid JSON content at ID: 4124640830, attempting eval...
# Start API call at ID: 4125122297, Retry: 0
# Retrieved dictionary at ID: 4125122297
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125122297, attempting eval...
# Start API call at ID: 4125654156, Retry: 0
# Retrieved dictionary at ID: 4125654156
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": 122007,
#     "max_yearly_salary": 183010,
#     "degree": "BS",
#     "skills": ["digital", "data", "strategy", "management", "innovation", "communication", "organization"]
# }
# Start API call at ID: 4125208676, Retry: 0
# Retrieved dictionary at ID: 4125208676
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 183301,
#     "max_yearly_salary": 224034,
#     "degree": "BS",
#     "skills": ["mergers", "acquisitions", "PowerPoint", "Excel"]
# }
# Start API call at ID: 3237661176, Retry: 0
# Retrieved dictionary at ID: 3237661176
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["business analytics", "financial modeling", "ROI analysis", "SQL"]
# }
# Invalid JSON content at ID: 3237661176, attempting eval...
# Start API call at ID: 4126635778, Retry: 0
# Retrieved dictionary at ID: 4126635778
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "GAAP", "project management", "accounting"]
# }
# Invalid JSON content at ID: 4126635778, attempting eval...
# Start API call at ID: 4125116891, Retry: 0
# Retrieved dictionary at ID: 4125116891
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["leadership", "contract administration", "risk management", "project planning", "communication", "financial reporting", "safety"]
# }
# Invalid JSON content at ID: 4125116891, attempting eval...
# Start API call at ID: 4126512491, Retry: 0
# Retrieved dictionary at ID: 4126512491
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["problem-solving", "strategic decision-making", "electronic trading"]
# }
# Invalid JSON content at ID: 4126512491, attempting eval...
# Start API call at ID: 4125144095, Retry: 0
# Retrieved dictionary at ID: 4125144095
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "AS",
#     "skills": ["accounting", "finance", "Microsoft Excel", "organizational skills", "communication", "teamwork"]
# }
# Invalid JSON content at ID: 4125144095, attempting eval...
# Start API call at ID: 4125139727, Retry: 0
# Retrieved dictionary at ID: 4125139727
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 95000,
#     "max_yearly_salary": 110000,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "QuickBooks"]
# }
# Start API call at ID: 4124620437, Retry: 0
# Retrieved dictionary at ID: 4124620437
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 85000,
#     "degree": "BS",
#     "skills": [
#         "calendar management",
#         "travel management",
#         "expense management",
#         "project administration",
#         "budgeting",
#         "vendor invoicing",
#         "interpersonal skills",
#         "relationship management",
#         "Microsoft Office",
#         "SharePoint",
#         "Box"
#     ]
# }
# Start API call at ID: 4125168313, Retry: 0
# Retrieved dictionary at ID: 4125168313
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 54072,
#     "max_yearly_salary": 72852,
#     "degree": "BS",
#     "skills": ["data analytics", "communication", "Excel", "PowerPoint", "PowerBI", "Tableau", "python", "statistical modeling", "Adobe Analytics", "problem-solving"]
# }
# Invalid JSON content at ID: 4125168313, attempting eval...
# Start API call at ID: 4126541570, Retry: 0
# Retrieved dictionary at ID: 4126541570
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial analysis",
#         "communication",
#         "Microsoft Excel",
#         "PeopleSoft Financials",
#         "HFM",
#         "Blackline"
#     ]
# }
# Invalid JSON content at ID: 4126541570, attempting eval...
# Start API call at ID: 4125642048, Retry: 0
# Retrieved dictionary at ID: 4125642048
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": [
#         "finance",
#         "controlling",
#         "accounting",
#         "MS Excel",
#         "Power Point",
#         "SAP"
#     ]
# }
# Invalid JSON content at ID: 4125642048, attempting eval...
# Start API call at ID: 4125120374, Retry: 0
# Retrieved dictionary at ID: 4125120374
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["marketing", "hospitality", "tourism", "public relations", "economic development"]
# }
# Invalid JSON content at ID: 4125120374, attempting eval...
# Start API call at ID: 4125546032, Retry: 0
# Retrieved dictionary at ID: 4125546032
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "analytical",
#         "financial modeling",
#         "communication",
#         "leadership",
#         "collaboration"
#     ]
# }
# Invalid JSON content at ID: 4125546032, attempting eval...
# Start API call at ID: 4125161069, Retry: 0
# Retrieved dictionary at ID: 4125161069
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": 71544,
#     "max_yearly_salary": 76544,
#     "degree": None,
#     "skills": [
#         "financial analysis",
#         "procurement",
#         "cash management",
#         "financial software",
#         "Microsoft Excel",
#         "tax regulations",
#         "analytical",
#         "problem-solving"
#     ]
# }
# Invalid JSON content at ID: 4125161069, attempting eval...
# Start API call at ID: 4125142382, Retry: 0
# Retrieved dictionary at ID: 4125142382
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["administrative", "customer-service", "communication", "Excel", "PowerPoint", "problem resolution"]
# }
# Invalid JSON content at ID: 4125142382, attempting eval...
# Start API call at ID: 4126506105, Retry: 0
# Retrieved dictionary at ID: 4126506105
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 60200,
#     "max_yearly_salary": 128800,
#     "degree": "BS",
#     "skills": ["finance", "project management", "accounting", "process design", "user acceptance testing"]
# }
# Start API call at ID: 4125219260, Retry: 0
# Retrieved dictionary at ID: 4125219260
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": 190000,
#     "max_yearly_salary": 250000,
#     "degree": "BS",
#     "skills": [
#         "management",
#         "budgeting",
#         "communication",
#         "supervision",
#         "accounting",
#         "client service",
#         "MS Suite"
#     ]
# }
# Start API call at ID: 4126197372, Retry: 0
# Retrieved dictionary at ID: 4126197372
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": 65000,
#     "max_yearly_salary": 75000,
#     "degree": "BS",
#     "skills": ["credit", "collections", "Excel", "accounting"]
# }
# Start API call at ID: 4124362028, Retry: 0
# Retrieved dictionary at ID: 4124362028
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["analytical", "financial planning", "forecasting", "financial modeling", "SAP", "MS Office"]
# }
# Invalid JSON content at ID: 4124362028, attempting eval...
# Start API call at ID: 4124396033, Retry: 0
# Retrieved dictionary at ID: 4124396033
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Accounting", "Financial Analysis", "Excel", "PowerPoint"]
# }
# Invalid JSON content at ID: 4124396033, attempting eval...
# Start API call at ID: 4124685198, Retry: 0
# Retrieved dictionary at ID: 4124685198
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": 185000,
#     "degree": "BS",
#     "skills": [
#         "Agile",
#         "project management",
#         "Treasury",
#         "ACH",
#         "banking",
#         "credit card",
#         "communication",
#         "problem solving"
#     ]
# }
# Start API call at ID: 4124654759, Retry: 0
# Retrieved dictionary at ID: 4124654759
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Financial Statements", "Financial Reporting", "Accounting", "Analytical Skills", "Finance"]
# }
# Invalid JSON content at ID: 4124654759, attempting eval...
# Start API call at ID: 4125165035, Retry: 0
# Retrieved dictionary at ID: 4125165035
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125165035, attempting eval...
# Start API call at ID: 4125200261, Retry: 0
# Retrieved dictionary at ID: 4125200261
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 110000,
#     "degree": None,
#     "skills": ["banking", "regulations", "lending"]
# }
# Invalid JSON content at ID: 4125200261, attempting eval...
# Start API call at ID: 4126537454, Retry: 0
# Retrieved dictionary at ID: 4126537454
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "GAAP", "Sage Intacct", "Sage 300", "Sage 100", "job costing", "financial reporting"]
# }
# Invalid JSON content at ID: 4126537454, attempting eval...
# Start API call at ID: 4124390812, Retry: 0
# Retrieved dictionary at ID: 4124390812
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 76000,
#     "max_yearly_salary": 109000,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4124390812, attempting eval...
# Start API call at ID: 4125217965, Retry: 0
# Retrieved dictionary at ID: 4125217965
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "GAAP",
#         "accounting",
#         "financial processes",
#         "data analysis",
#         "forecasting",
#         "communication",
#         "problem-solving"
#     ]
# }
# Invalid JSON content at ID: 4125217965, attempting eval...
# Start API call at ID: 4126527366, Retry: 0
# Retrieved dictionary at ID: 4126527366
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": 150000,
#     "degree": None,
#     "skills": ["writing", "finance", "accounting", "communication", "Excel", "Word", "PowerPoint", "Bloomberg", "FactSet", "Python"]
# }
# Invalid JSON content at ID: 4126527366, attempting eval...
# Start API call at ID: 4126530225, Retry: 0
# Retrieved dictionary at ID: 4126530225
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": 50000,
#     "max_yearly_salary": None,
#     "degree": "AS",
#     "skills": ["accounting", "finance", "cost accounting", "Excel", "organizational skills", "communication"]
# }
# Invalid JSON content at ID: 4126530225, attempting eval...
# Start API call at ID: 4125106648, Retry: 0
# Retrieved dictionary at ID: 4125106648
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial", "accounting", "management", "healthcare", "risk"]
# }
# Invalid JSON content at ID: 4125106648, attempting eval...
# Start API call at ID: 4126605778, Retry: 0
# Retrieved dictionary at ID: 4126605778
# {
#     "min_years_of_experience": 20,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "strategic planning",
#         "data-driven decision-making",
#         "business strategy",
#         "performance improvement",
#         "analytics"
#     ]
# }
# Invalid JSON content at ID: 4126605778, attempting eval...
# Start API call at ID: 4124337042, Retry: 0
# Retrieved dictionary at ID: 4124337042
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["finance", "accounting", "writing", "analytic", "Power Bi", "data analysis", "excel", "process mapping"]
# }
# Invalid JSON content at ID: 4124337042, attempting eval...
# Start API call at ID: 4126533783, Retry: 0
# Retrieved dictionary at ID: 4126533783
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "GAAP", "financial reporting", "Excel"]
# }
# Invalid JSON content at ID: 4126533783, attempting eval...
# Start API call at ID: 4124348757, Retry: 0
# Retrieved dictionary at ID: 4124348757
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "Microsoft Office",
#         "financial software",
#         "analytical skills",
#         "problem-solving",
#         "communication"
#     ]
# }
# Invalid JSON content at ID: 4124348757, attempting eval...
# Start API call at ID: 4126621177, Retry: 0
# Retrieved dictionary at ID: 4126621177
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["accounting", "construction project", "leadership", "ERP", "analytical", "communication"]
# }
# Invalid JSON content at ID: 4126621177, attempting eval...
# Start API call at ID: 4123854828, Retry: 0
# Retrieved dictionary at ID: 4123854828
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["analytical", "financial modeling", "communication", "collaboration", "MS Office"]
# }
# Invalid JSON content at ID: 4123854828, attempting eval...
# Start API call at ID: 4126620252, Retry: 0
# Retrieved dictionary at ID: 4126620252
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 60200,
#     "max_yearly_salary": 128800,
#     "degree": "BS",
#     "skills": ["financial planning", "forecasting", "analysis", "cost management", "Tableau", "SQL", "data mining"]
# }
# Start API call at ID: 4124327658, Retry: 0
# Retrieved dictionary at ID: 4124327658
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "leadership",
#         "analytical",
#         "sales",
#         "portfolio management",
#         "communication",
#         "problem-solving",
#         "Excel",
#         "PowerPoint",
#         "Power BI"
#     ]
# }
# Invalid JSON content at ID: 4124327658, attempting eval...
# Start API call at ID: 4125165567, Retry: 0
# Retrieved dictionary at ID: 4125165567
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 90000,
#     "max_yearly_salary": 115000,
#     "degree": "BS",
#     "skills": ["Netsuite", "Microsoft Office", "Excel"]
# }
# Start API call at ID: 4125255185, Retry: 0
# Retrieved dictionary at ID: 4125255185
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 100000,
#     "max_yearly_salary": 140000,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125255185, attempting eval...
# Start API call at ID: 4124996449, Retry: 0
# Retrieved dictionary at ID: 4124996449
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "analytical", "financial analysis", "accounting", "project based accounting", "government contracts", "FAR"]
# }
# Invalid JSON content at ID: 4124996449, attempting eval...
# Start API call at ID: 4126615174, Retry: 0
# Retrieved dictionary at ID: 4126615174
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Yardi", "Excel", "Real Estate", "Property Management", "Construction"]
# }
# Invalid JSON content at ID: 4126615174, attempting eval...
# Start API call at ID: 4125179517, Retry: 0
# Retrieved dictionary at ID: 4125179517
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial reports", "bank reconciliations", "audits", "budgeting", "forecasting", "Microsoft Office"]
# }
# Invalid JSON content at ID: 4125179517, attempting eval...
# Start API call at ID: 4126537784, Retry: 0
# Retrieved dictionary at ID: 4126537784
# {
#     "min_years_of_experience": 7,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["budgeting", "financial analysis", "reporting"]
# }
# Invalid JSON content at ID: 4126537784, attempting eval...
# Start API call at ID: 4124618593, Retry: 0
# Retrieved dictionary at ID: 4124618593
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 85000,
#     "degree": "BS",
#     "skills": [
#         "calendar management",
#         "travel management",
#         "expense management",
#         "meeting preparation",
#         "vendor invoicing",
#         "project administration",
#         "budgeting",
#         "invoicing",
#         "interpersonal skills",
#         "relationship management",
#         "Microsoft Office Suite",
#         "Concur",
#         "SharePoint",
#         "Box"
#     ]
# }
# Start API call at ID: 4126525187, Retry: 0
# Retrieved dictionary at ID: 4126525187
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial planning", "wealth management", "CRM", "analytical", "communication"]
# }
# Invalid JSON content at ID: 4126525187, attempting eval...
# Start API call at ID: 4125138783, Retry: 0
# Retrieved dictionary at ID: 4125138783
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 0,
#     "max_yearly_salary": 0,
#     "degree": "BS",
#     "skills": ["financial analysis", "ALM", "Excel", "SQL", "VBA", "financial modeling"]
# }
# Start API call at ID: 4124382983, Retry: 0
# Retrieved dictionary at ID: 4124382983
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 103000,
#     "max_yearly_salary": 137400,
#     "degree": "BS",
#     "skills": [
#         "financial analysis",
#         "budgeting",
#         "forecasting",
#         "reporting",
#         "Excel",
#         "Adaptive Insights",
#         "NetSuite",
#         "Power BI"
#     ]
# }
# Start API call at ID: 4124620432, Retry: 0
# Retrieved dictionary at ID: 4124620432
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 70000,
#     "max_yearly_salary": 85000,
#     "degree": "BS",
#     "skills": [
#         "calendar management",
#         "travel management",
#         "expense management",
#         "meeting preparation",
#         "vendor invoicing",
#         "project administration",
#         "budgeting",
#         "invoicing",
#         "interpersonal skills",
#         "relationship management",
#         "computer skills",
#         "Microsoft Office",
#         "project management"
#     ]
# }
# Start API call at ID: 4126544005, Retry: 0
# Retrieved dictionary at ID: 4126544005
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": [
#         "healthcare administration",
#         "behavioral health",
#         "mental health",
#         "psychiatric treatment",
#         "team management",
#         "communication"
#     ]
# }
# ...
#     "max_yearly_salary": 18 * 40 * 52,
#     "degree": None,
#     "skills": ["accounting", "financial statements", "accounting software", "data entry", "Excel", "Word"]
# }
# Invalid JSON content at ID: 4125176556, attempting eval...
# Error during API call or processing at ID: 4125176556: malformed node or string on line 3: <ast.BinOp object at 0x000001C541998690>
# Retrying 9... Waiting before next attempt.
# Start API call at ID: 4125176556, Retry: 9
# Retrieved dictionary at ID: 4125176556
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 35240,
#     "max_yearly_salary": 37440,
#     "degree": None,
#     "skills": ["financial records", "financial statements", "accounting", "audits", "budgeting", "data entry", "Excel", "Word"]
# }
# Invalid JSON content at ID: 4125176556, attempting eval...
# Start API call at ID: 4126602551, Retry: 0
# Retrieved dictionary at ID: 4126602551
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["Excel", "Outlook", "Word"]
# }
# Invalid JSON content at ID: 4126602551, attempting eval...
# Start API call at ID: 4125119504, Retry: 0
# Retrieved dictionary at ID: 4125119504
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": 98100,
#     "max_yearly_salary": 147100,
#     "degree": "BS",
#     "skills": ["Financial Reporting", "Financial Analysis", "Excel", "Accounting", "Compliance"]
# }
# Start API call at ID: 4124996066, Retry: 0
# Retrieved dictionary at ID: 4124996066
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 125000,
#     "max_yearly_salary": 210000,
#     "degree": "BS",
#     "skills": ["accounting", "financial analysis", "budgeting", "forecasting", "strategic planning"]
# }
# Start API call at ID: 4124989649, Retry: 0
# Retrieved dictionary at ID: 4124989649
# {
#     "min_years_of_experience": 0,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "finance", "MS Office"]
# }
# Invalid JSON content at ID: 4124989649, attempting eval...
# Start API call at ID: 4124682581, Retry: 0
# Retrieved dictionary at ID: 4124682581
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": 185000,
#     "degree": "BS",
#     "skills": [
#         "Agile",
#         "Treasury",
#         "ACH",
#         "project management",
#         "communication",
#         "problem solving",
#         "analytical"
#     ]
# }
# Start API call at ID: 4126502739, Retry: 0
# Retrieved dictionary at ID: 4126502739
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "client service",
#         "communication",
#         "Microsoft Office",
#         "writing",
#         "organizational",
#         "collaboration",
#         "goal oriented"
#     ]
# }
# Invalid JSON content at ID: 4126502739, attempting eval...
# Start API call at ID: 4125534274, Retry: 0
# Retrieved dictionary at ID: 4125534274
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 108000,
#     "max_yearly_salary": 158000,
#     "degree": None,
#     "skills": ["SQL", "analytical problem-solving", "quantitative analysis", "business strategy"]
# }
# Invalid JSON content at ID: 4125534274, attempting eval...
# Start API call at ID: 4125118906, Retry: 0
# Retrieved dictionary at ID: 4125118906
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial analysis", "Excel", "PowerPoint", "Word", "Microsoft Office"]
# }
# Invalid JSON content at ID: 4125118906, attempting eval...
# Start API call at ID: 4125174619, Retry: 0
# Retrieved dictionary at ID: 4125174619
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 175000,
#     "max_yearly_salary": 190000,
#     "degree": "BS",
#     "skills": [
#         "Lean Manufacturing",
#         "5S",
#         "Six Sigma",
#         "sustainable manufacturing",
#         "technical drawings",
#         "report writing",
#         "mathematics",
#         "MS Word",
#         "Excel",
#         "PowerPoint",
#         "Business Intelligence",
#         "ERP",
#         "performance metrics",
#         "leadership",
#         "OSHA",
#         "EPA",
#         "coaching",
#         "financial performance",
#         "new product introduction",
#         "engineering change management",
#         "ISO"
#     ]
# }
# Start API call at ID: 4125248825, Retry: 0
# Retrieved dictionary at ID: 4125248825
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial management",
#         "cash flow analysis",
#         "budget management",
#         "report preparation",
#         "project management"
#     ]
# }
# Invalid JSON content at ID: 4125248825, attempting eval...
# Start API call at ID: 4123897716, Retry: 0
# Retrieved dictionary at ID: 4123897716
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 114000,
#     "max_yearly_salary": 167000,
#     "degree": "BS",
#     "skills": [
#         "data modeling",
#         "reporting",
#         "advertising",
#         "consultative sales",
#         "business development",
#         "digital media"
#     ]
# }
# Start API call at ID: 4125169379, Retry: 0
# Retrieved dictionary at ID: 4125169379
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 110520,
#     "max_yearly_salary": 165840,
#     "degree": "BS",
#     "skills": [
#         "analysis",
#         "financial planning",
#         "communication",
#         "decision making",
#         "inventory reporting",
#         "SAP",
#         "cost accounting"
#     ]
# }
# Invalid JSON content at ID: 4125169379, attempting eval...
# Start API call at ID: 4125165926, Retry: 0
# Retrieved dictionary at ID: 4125165926
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 0,
#     "max_yearly_salary": 0,
#     "degree": "BS",
#     "skills": [
#         "financial analytical thinking",
#         "GAAP",
#         "financial analysis",
#         "modeling",
#         "procurement",
#         "budgeting",
#         "forecasting",
#         "communication"
#     ]
# }
# Start API call at ID: 4125170354, Retry: 0
# Retrieved dictionary at ID: 4125170354
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 61600,
#     "max_yearly_salary": 114400,
#     "degree": None,
#     "skills": ["customer service", "analysis", "team skills", "communication", "technical proficiency", "problem solving", "data driven"]
# }
# Invalid JSON content at ID: 4125170354, attempting eval...
# Start API call at ID: 4126535288, Retry: 0
# Retrieved dictionary at ID: 4126535288
# {
#     "min_years_of_experience": 0,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial modeling",
#         "organizational",
#         "multi-tasking",
#         "communication",
#         "analytical"
#     ]
# }
# Invalid JSON content at ID: 4126535288, attempting eval...
# Start API call at ID: 4124329429, Retry: 0
# Retrieved dictionary at ID: 4124329429
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial analysis", "P&L management", "strategic planning"]
# }
# Invalid JSON content at ID: 4124329429, attempting eval...
# Start API call at ID: 4125163901, Retry: 0
# Retrieved dictionary at ID: 4125163901
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": ["financial reporting", "budgeting", "data analysis", "organizational skills", "team management"]
# }
# Invalid JSON content at ID: 4125163901, attempting eval...
# Start API call at ID: 4125109090, Retry: 0
# Retrieved dictionary at ID: 4125109090
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": [
#         "leadership",
#         "strategic thinking",
#         "communication",
#         "financial acumen",
#         "adaptability"
#     ]
# }
# Invalid JSON content at ID: 4125109090, attempting eval...
# Start API call at ID: 4125131310, Retry: 0
# Retrieved dictionary at ID: 4125131310
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": 85000,
#     "max_yearly_salary": 95000,
#     "degree": "BS",
#     "skills": [
#         "finance",
#         "accounting",
#         "communication",
#         "analytical",
#         "Excel",
#         "PowerBI",
#         "data visualization"
#     ]
# }
# Start API call at ID: 4124395284, Retry: 0
# Retrieved dictionary at ID: 4124395284
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 76000,
#     "max_yearly_salary": 109000,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4124395284, attempting eval...
# Start API call at ID: 4126520351, Retry: 0
# Retrieved dictionary at ID: 4126520351
# {
#     "min_years_of_experience": 1,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["Excel", "communication", "teamwork", "attention to detail", "risk management"]
# }
# Invalid JSON content at ID: 4126520351, attempting eval...
# Start API call at ID: 4125224083, Retry: 0
# Retrieved dictionary at ID: 4125224083
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": None
# }
# Invalid JSON content at ID: 4125224083, attempting eval...
# Start API call at ID: 4125101044, Retry: 0
# Retrieved dictionary at ID: 4125101044
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "commercial lending",
#         "SBA loans",
#         "credit skills",
#         "customer service",
#         "strategic planning",
#         "project management",
#         "Microsoft Office"
#     ]
# }
# Invalid JSON content at ID: 4125101044, attempting eval...
# Start API call at ID: 4125180438, Retry: 0
# Retrieved dictionary at ID: 4125180438
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 31200,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "communication",
#         "computer proficiency",
#         "MS Office"
#     ]
# }
# Invalid JSON content at ID: 4125180438, attempting eval...
# Start API call at ID: 4125212021, Retry: 0
# Retrieved dictionary at ID: 4125212021
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["reporting", "Excel", "database"]
# }
# Invalid JSON content at ID: 4125212021, attempting eval...
# Start API call at ID: 4125531071, Retry: 0
# Retrieved dictionary at ID: 4125531071
# {
#     "min_years_of_experience": 15,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "MS",
#     "skills": [
#         "Corporate Governance",
#         "Strategic Planning",
#         "Financial Acumen",
#         "Risk Management",
#         "Regulatory Compliance",
#         "Stakeholder Engagement",
#         "Leadership Development",
#         "Mergers and Acquisitions"
#     ]
# }
# Invalid JSON content at ID: 4125531071, attempting eval...
# Start API call at ID: 4124664502, Retry: 0
# Retrieved dictionary at ID: 4124664502
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": None,
#     "skills": ["KYC", "client onboarding", "financial services", "regulatory", "compliance"]
# }
# Invalid JSON content at ID: 4124664502, attempting eval...
# Start API call at ID: 4125169263, Retry: 0
# Retrieved dictionary at ID: 4125169263
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 85000,
#     "max_yearly_salary": 105000,
#     "degree": "BS",
#     "skills": ["analytical", "Microsoft Excel", "communication"]
# }
# Start API call at ID: 4124338009, Retry: 0
# Retrieved dictionary at ID: 4124338009
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "procurement",
#         "public safety",
#         "emergency management",
#         "problem-solving",
#         "communications",
#         "analytical",
#         "organizational",
#         "time management"
#     ]
# }
# Invalid JSON content at ID: 4124338009, attempting eval...
# Start API call at ID: 4126520070, Retry: 0
# Retrieved dictionary at ID: 4126520070
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 125000,
#     "max_yearly_salary": 155000,
#     "degree": "BS",
#     "skills": [
#         "payments",
#         "risk management",
#         "project management",
#         "compliance",
#         "digital banking",
#         "ACH",
#         "wire",
#         "credit card",
#         "vendor management",
#         "organization"
#     ]
# }
# Start API call at ID: 4124695868, Retry: 0
# Retrieved dictionary at ID: 4124695868
# {
#     "min_years_of_experience": 3,
#     "min_yearly_salary": 127000,
#     "max_yearly_salary": 172000,
#     "degree": None,
#     "skills": ["SQL", "Python", "Excel", "data analysis", "financial analysis", "mobile payments", "financial technology"]
# }
# Invalid JSON content at ID: 4124695868, attempting eval...
# Start API call at ID: 4126537071, Retry: 0
# Retrieved dictionary at ID: 4126537071
# {
#     "min_years_of_experience": 10,
#     "min_yearly_salary": 154229,
#     "max_yearly_salary": 202425,
#     "degree": "BS",
#     "skills": [
#         "Treasury",
#         "banking",
#         "analytics",
#         "cash management",
#         "leadership"
#     ]
# }
# Start API call at ID: 4125235258, Retry: 0
# Retrieved dictionary at ID: 4125235258
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": 110000,
#     "max_yearly_salary": 140000,
#     "degree": "BS",
#     "skills": ["financial planning", "budgeting", "analytics", "cash flow", "procurement", "cost control", "financial modeling"]
# }
# Start API call at ID: 4126519685, Retry: 0
# Retrieved dictionary at ID: 4126519685
# {
#     "min_years_of_experience": 2,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial analysis", "property tax", "Microsoft Excel", "PowerBI", "accounting software"]
# }
# Invalid JSON content at ID: 4126519685, attempting eval...
# Start API call at ID: 4125214794, Retry: 0
# Retrieved dictionary at ID: 4125214794
# {
#     "min_years_of_experience": 6,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["financial management", "operational leadership", "internal controls", "risk assessment", "analytical insights", "Microsoft Office"]
# }
# Invalid JSON content at ID: 4125214794, attempting eval...
# Start API call at ID: 4126639176, Retry: 0
# Retrieved dictionary at ID: 4126639176
# {
#     "min_years_of_experience": 4,
#     "min_yearly_salary": 114600,
#     "max_yearly_salary": 143200,
#     "degree": None,
#     "skills": ["fundraising", "data analysis", "project management", "CRM"]
# }
# Invalid JSON content at ID: 4126639176, attempting eval...
# Start API call at ID: 4125138797, Retry: 0
# Retrieved dictionary at ID: 4125138797
# {
#     "min_years_of_experience": 8,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": ["accounting", "financial reporting", "leadership", "communication", "analytics", "process improvements", "automation"]
# }
# Invalid JSON content at ID: 4125138797, attempting eval...
# Start API call at ID: 4126605734, Retry: 0
# Retrieved dictionary at ID: 4126605734
# {
#     "min_years_of_experience": None,
#     "min_yearly_salary": 43000,
#     "max_yearly_salary": 48000,
#     "degree": "BS",
#     "skills": [
#         "communication",
#         "organization",
#         "risk review",
#         "credit analysis"
#     ]
# }
# Invalid JSON content at ID: 4126605734, attempting eval...
# Start API call at ID: 4125113124, Retry: 0
# Retrieved dictionary at ID: 4125113124
# {
#     "min_years_of_experience": 5,
#     "min_yearly_salary": None,
#     "max_yearly_salary": None,
#     "degree": "BS",
#     "skills": [
#         "financial management",
#         "budgeting",
#         "financial analysis",
#         "communication",
#         "leadership",
#         "Microsoft Office",
#         "Excel",
#         "payroll processing"
#     ]
# }
# Invalid JSON content at ID: 4125113124, attempting eval...

# %%
df5.to_csv('01152025_linkedin_fin_location_title_ai.csv', index=False)

# %%
df5 = pd.read_csv('01152025_linkedin_fin_location_title_ai.csv')

# %%
# parse salary and calculate average salary from low and high end
df6 = df5.apply(parse_salary, axis=1)

# %%
df6.to_csv('01152025_linkedin_fin_location_title_ai_salary.csv', index=False)

# %%
df6 = pd.read_csv('01152025_linkedin_fin_location_title_ai_salary.csv')

# %%
df7 = standard_skills(df6)

# %%
df7.to_csv('01152025_linkedin_fin_location_title_ai_salary_skill.csv', index=False)

# %%
df7_exploded = df7.explode('skills_clean')
df7_exploded = df7_exploded.dropna(subset=['skills_clean'])
skill_counts = df7_exploded['skills_clean'].value_counts()
skill_counts.to_csv('skill_counts.csv')
