# %%
import pandas as pd

# %%
path = 'D:/Learn/projects/data/job_data/mine/'
file = 'companies_info.csv'

# %%
df = pd.read_csv(f'{path}{file}')
df.head(3)
# Out:
#                                         company_name  \
# 0                          Amazon Web Services (AWS)
# 1  NYC Department of Housing Preservation & Devel...
# 2                                                TCW
#
#                                          company_url  \
# 0  https://www.linkedin.com/company/amazon-web-se...
# 1  https://www.linkedin.com/company/nyc-dept.-of-...
# 2  https://www.linkedin.com/company/thetcwgroup?t...
#
#                                            clean_url  \
# 0  https://www.linkedin.com/company/amazon-web-se...
# 1  https://www.linkedin.com/company/nyc-dept.-of-...
# 2      https://www.linkedin.com/company/thetcwgroup/
#
#                                                 Name            Followers  \
# 0                          Amazon Web Services (AWS)  ('10M  followers',)
# 1  NYC Department of Housing Preservation & Devel...  ('21K  followers',)
# 2                                                TCW  ('20K  followers',)
#
# ...

# %%
df['Industry'].value_counts()[:20]
# Out:
# Industry
# Staffing and Recruiting                 193
# Financial Services                      122
# Hospitals and Health Care                86
# IT Services and IT Consulting            80
# Software Development                     65
# Insurance                                37
# Business Consulting and Services         36
# Real Estate                              36
# Higher Education                         33
# Retail                                   27
# Government Administration                23
# Banking                                  19
# Defense and Space Manufacturing          19
# Technology, Information and Internet     19
# Information Technology & Services        17
# Biotechnology Research                   15
# Construction                             14
# Manufacturing                            14
# Motor Vehicle Manufacturing              13
# Hospitality                              12
# Name: count, dtype: int64

# %%
df[(df['Industry']=='Staffing and Recruiting') & (df['Members']>1) & (df['Verified page'].notna())]
# Out:
#            company_name                                        company_url  \
# 3                 Jobot  https://www.linkedin.com/company/jobot?trk=pub...
# 4           Robert Half  https://www.linkedin.com/company/robert-half-i...
# 8        Atlantic Group  https://www.linkedin.com/company/the-atlantic-...
# 17        StevenDouglas  https://www.linkedin.com/company/stevendouglas...
# 22    Proven Recruiting  https://www.linkedin.com/company/proven-recrui...
# ...                 ...                                                ...
# 1139       Pride Health  https://www.linkedin.com/company/pride-health?...
# 1144    24 Seven Talent  https://www.linkedin.com/company/24seventalent...
# 1153     AccruePartners  https://www.linkedin.com/company/accruepartner...
# 1155  US Tech Solutions  https://www.linkedin.com/company/us-tech-solut...
# 1195    Dahl Consulting  https://www.linkedin.com/company/dahl-consulti...
#
# ...
